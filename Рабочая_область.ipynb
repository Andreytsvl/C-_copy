# %% [markdown]
# <a href="https://colab.research.google.com/github/Andreytsvl/C-_copy/blob/main/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B0%D1%8F_%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82%D1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd
a= [54,6,11,True]
print(a)
do = pd.Series(a)

tuple(do)
# Out:
# [54, 6, 11, True]
# (54, 6, 11, True)

# %%
a
# Out:
# [54, 6, 11, True]

# %% [markdown]
# # ***'hello world'a\***

# %%
a=[True, False, True]
print(a)
s = pd.Series(['ghbdtn', 'vbh', 'ghj'])
print(s)


y= pd.Series(list('wold'))
print(y+ 'dfg')
s.index
# Out:
# [True, False, True]
# 0    ghbdtn
# 1       vbh
# 2       ghj
# dtype: object
# 0    wdfg
# 1    odfg
# 2    ldfg
# 3    ddfg
# dtype: object
# RangeIndex(start=0, stop=3, step=1)

# %%
print (3+4)
print (3/4)
print (3+6)
a
# Out:
# 7
# 0.75
# 9
# [54, 6, 11, True]

# %%
d = pd.Series(range(100,10,-2))

d.sort_values()
# Out:
# 0     100
# 1      98
# 2      96
# 3      94
# 4      92
# 5      90
# 6      88
# 7      86
# 8      84
# 9      82
# 10     80
# 11     78
# 12     76
# 13     74
# 14     72
# 15     70
# 16     68
# 17     66
# 18     64
# 19     62
# 20     60
# 21     58
# 22     56
# 23     54
# 24     52
# 25     50
# 26     48
# 27     46
# 28     44
# 29     42
# 30     40
# 31     38
# 32     36
# 33     34
# 34     32
# 35     30
# 36     28
# 37     26
# 38     24
# 39     22
# 40     20
# 41     18
# 42     16
# 43     14
# 44     12
# dtype: int64

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head(60)
# Out:
#    whoAmI
# 0   robot
# 1   human
# 2   robot
# 3   human
# 4   human
# 5   robot
# 6   robot
# 7   robot
# 8   robot
# 9   human
# 10  human
# 11  human
# 12  human
# 13  robot
# 14  robot
# 15  human
# 16  human
# 17  robot
# 18  human
# 19  robot

# %%
pd.get_dummies(data['whoAmI'])
# Out:
#     human  robot
# 0       0      1
# 1       1      0
# 2       0      1
# 3       1      0
# 4       1      0
# 5       0      1
# 6       0      1
# 7       0      1
# 8       0      1
# 9       1      0
# 10      1      0
# 11      1      0
# 12      1      0
# 13      0      1
# 14      0      1
# 15      1      0
# 16      1      0
# 17      0      1
# 18      1      0
# 19      0      1
